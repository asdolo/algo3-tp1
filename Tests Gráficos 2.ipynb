# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# <h3>Complejidad Fuerza Bruta</h3>

# %%
df_complejidad_fb = pd.read_csv('output/mediciones-fuerzabruta.csv')
del df_complejidad_fb['resultado']

# Obtengo el promedio
df_complejidad_fb = df_complejidad_fb.groupby(['n', 'V'], as_index=False, sort=False).mean()

# grafico
a4_dims = (10.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 1))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

df_complejidad_fb['fb/n*2^n'] = df_complejidad_fb['tiempo'] / (df_complejidad_fb['n'] * (2**df_complejidad_fb['n']));

ax1 = sns.lineplot(x="n", y="fb/n*2^n", data=df_complejidad_fb, ax=ax);
plt.ylim(-0.05,0.05);

plt.ylabel(r"Relación $\frac{FuerzaBruta(n, V)}{n\times 2^{n}}$", fontsize=16);
plt.xlabel(r"$n$", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None]

# %%
# grafico
a4_dims = (10.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 7))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1 = sns.lineplot(x="V", y="tiempo", data=df_complejidad_fb.loc[df_complejidad_fb['n'] == 14], label="n=14", ax=ax);
ax1 = sns.lineplot(x="V", y="tiempo", data=df_complejidad_fb.loc[df_complejidad_fb['n'] == 15], label="n=15", ax=ax);
ax1 = sns.lineplot(x="V", y="tiempo", data=df_complejidad_fb.loc[df_complejidad_fb['n'] == 16], label="n=16", ax=ax);
ax1 = sns.lineplot(x="V", y="tiempo", data=df_complejidad_fb.loc[df_complejidad_fb['n'] == 17], label="n=17", ax=ax);
ax1 = sns.lineplot(x="V", y="tiempo", data=df_complejidad_fb.loc[df_complejidad_fb['n'] == 18], label="n=18", ax=ax);
ax1 = sns.lineplot(x="V", y="tiempo", data=df_complejidad_fb.loc[df_complejidad_fb['n'] == 19], label="n=19", ax=ax);
ax1 = sns.lineplot(x="V", y="tiempo", data=df_complejidad_fb.loc[df_complejidad_fb['n'] == 20], label="n=20", ax=ax);

#Reverse legends
handles, labels = ax1.get_legend_handles_labels()
ax1.legend(reversed(handles), reversed(labels), title='Líneas', loc='upper right')

plt.ylabel("FuerzaBruta(n,V) [ms]", fontsize=16);
plt.xlabel("V", fontsize=16);




plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None, None, None, None, None, None]

# %% [markdown]
# <h3>Complejidad Backtracking</h3>

# %%
df_complejidad_bt = pd.read_csv('output/mediciones-backtracking.csv')
del df_complejidad_bt['resultado']

# Obtengo el promedio
df_complejidad_bt = df_complejidad_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()

# grafico
a4_dims = (6.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 1))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

df_complejidad_bt['bt/n*2^n'] = df_complejidad_bt['tiempo'] / (df_complejidad_bt['n'] * (2**df_complejidad_bt['n']));

ax1 = sns.lineplot(x="n", y="bt/n*2^n", data=df_complejidad_bt, ax=ax);
plt.ylim(-0.05,0.05);

plt.ylabel(r"Relación $\frac{Backtracking(n, V)}{n\times 2^{n}}$", fontsize=16);
plt.xlabel(r"$n$", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)

# %% [markdown]
# <h3>Complejidad Programación Dinámica</h3>

# %%
df_complejidad_pd = pd.read_csv('output/mediciones-programaciondinamica.csv')
del df_complejidad_pd['resultado']

# Obtengo el promedio
df_complejidad_pd = df_complejidad_pd.groupby(['n', 'V'], as_index=False, sort=False).mean()

# grafico
a4_dims = (10.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 1))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

df_complejidad_pd['n*V'] = df_complejidad_pd['n'] * df_complejidad_pd['V']
df_complejidad_pd['pd/n*V'] = df_complejidad_pd['tiempo'] / (df_complejidad_pd['n'] * df_complejidad_pd['V'])

ax1 = sns.lineplot(x="n*V", y="pd/n*V", data=df_complejidad_pd, ax=ax)
plt.ylim(-0.1,0.10);

plt.ylabel(r"Relación $\frac{ProgramaciónDinámica(n, V)}{n\times V}$", fontsize=16)
plt.xlabel(r"$n \times V$", fontsize=16)
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None]

# %% [markdown]
# <h1>Experimento 1</h1>
# Fuerza Bruta vs Backtracking (sin podas)

# %%
df_test_1_fb = pd.read_csv('output/test-1-fuerzabruta.csv')
del df_test_1_fb['resultado']

df_test_1_bt = pd.read_csv('output/test-1-backtracking.csv')
del df_test_1_bt['resultado']

# Obtengo el promedio en cada tabla
df_test_1_fb = df_test_1_fb.groupby(['n', 'V'], as_index=False, sort=False).mean()
df_test_1_bt = df_test_1_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()

# renombro las columnas en cada dataframe y los mergeo en uno solo
df_test_1_fb.columns = ['n', 'V', 'tiempo (fuerzabruta)']
df_test_1_bt.columns = ['n', 'V', 'tiempo (backtracking)']

df_test_1 = df_test_1_fb
df_test_1['tiempo (backtracking)'] = df_test_1_bt['tiempo (backtracking)']

# grafico
a4_dims = (6.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 2))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))


ax1 = sns.lineplot(x="n", y="tiempo (fuerzabruta)", data=df_test_1, label='Fuerza Bruta', ax=ax);
ax1 = sns.lineplot(x="n", y="tiempo (backtracking)", data=df_test_1, label='Backtracking', ax=ax);


plt.ylabel("Tiempo de ejecución [ms]", fontsize=16);
plt.xlabel("n", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None, None]

# %% [markdown]
# <h1>Experimento 2</h1>
# Fuerza Bruta vs Backtracking (con podas)

# %% [markdown]
# <h3>Poda de medio árbol</h3>
# Complejidad practica esperada: O(n*2^n/2)

# %%
df_test_2_a_fb = pd.read_csv('output/test-2-a-fuerzabruta.csv')
del df_test_2_a_fb['resultado']

df_test_2_a_bt = pd.read_csv('output/test-2-a-backtracking.csv')
del df_test_2_a_bt['resultado']

# Obtengo el promedio en cada tabla
df_test_2_a_fb = df_test_2_a_fb.groupby(['n', 'V'], as_index=False, sort=False).mean()
df_test_2_a_bt = df_test_2_a_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()

# renombro las columnas en cada dataframe y los mergeo en uno solo
df_test_2_a_fb.columns = ['n', 'V', 'tiempo (fuerzabruta)']
df_test_2_a_bt.columns = ['n', 'V', 'tiempo (backtracking)']

df_test_2_a = df_test_2_a_fb
df_test_2_a['tiempo (backtracking)'] = df_test_2_a_bt['tiempo (backtracking)']

# grafico
a4_dims = (6.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 3))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1 = sns.lineplot(x="n", y="tiempo (fuerzabruta)", data=df_test_2_a, label='Fuerza Bruta', ax=ax);
ax1 = sns.lineplot(x="n", y="tiempo (backtracking)", data=df_test_1, label='Backtracking (Sin podas - Experimento 1)', ax=ax);
ax1 = sns.lineplot(x="n", y="tiempo (backtracking)", data=df_test_2_a, label='Backtracking (Poda de medio árbol)', ax=ax);


plt.ylabel("Tiempo de ejecución [ms]", fontsize=16);
plt.xlabel("n", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None, None, None]

# %% [markdown]
# <h3>Poda de todo el árbol</h3>
# Complejidad practica esperada: O(1)

# %%
df_test_2_b_fb = pd.read_csv('output/test-2-b-fuerzabruta.csv')
del df_test_2_b_fb['resultado']

df_test_2_b_bt = pd.read_csv('output/test-2-b-backtracking.csv')
del df_test_2_b_bt['resultado']

# Obtengo el promedio en cada tabla
df_test_2_b_fb = df_test_2_b_fb.groupby(['n', 'V'], as_index=False, sort=False).mean()
df_test_2_b_bt = df_test_2_b_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()

# renombro las columnas en cada dataframe y los mergeo en uno solo
df_test_2_b_fb.columns = ['n', 'V', 'tiempo (fuerzabruta)']
df_test_2_b_bt.columns = ['n', 'V', 'tiempo (backtracking)']

df_test_2_b = df_test_2_b_fb
df_test_2_b['tiempo (backtracking)'] = df_test_2_b_bt['tiempo (backtracking)']

# grafico
a4_dims = (6.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 2))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1 = sns.lineplot(x="n", y="tiempo (fuerzabruta)", data=df_test_2_b, label='Fuerza Bruta', ax=ax);
ax1 = sns.lineplot(x="n", y="tiempo (backtracking)", data=df_test_2_b, label='Backtracking (Poda de todo el árbol)', ax=ax);

plt.ylim(-0.05,2)

plt.ylabel("Tiempo de ejecución [ms]", fontsize=16);
plt.xlabel("n", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None, None]

# %% [markdown]
# <h3>Yapa: Extender el rango de n</h3>

# %%
df_test_2_b_yapa_bt = pd.read_csv('output/test-2-b-yapa-backtracking.csv')
del df_test_2_b_yapa_bt['resultado']

# Obtengo el promedio en cada tabla
df_test_2_b_yapa_bt = df_test_2_b_yapa_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()

# renombro las columnas en cada dataframe y los mergeo en uno solo
df_test_2_b_yapa_bt.columns = ['n', 'V', 'tiempo (backtracking)']

df_test_2_b_yapa = df_test_2_b_yapa_bt

# grafico
a4_dims = (6.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 1))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1 = sns.lineplot(x="n", y="tiempo (backtracking)", data=df_test_2_b_yapa, label='Backtracking (Poda de todo el árbol)', ax=ax);

plt.ylim(-0.05,2)

plt.ylabel("Tiempo de ejecución [ms]", fontsize=16);
plt.xlabel("n", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None]

# %% [markdown]
# <h3>Poda de todo el arbol menos una rama </h3>
# Complejidad practica esperada: O(n²)

# %%
df_test_2_c_fb = pd.read_csv('output/test-2-c-fuerzabruta.csv')
del df_test_2_c_fb['resultado']

df_test_2_c_bt = pd.read_csv('output/test-2-c-backtracking.csv')
del df_test_2_c_bt['resultado']

# Obtengo el promedio en cada tabla
df_test_2_c_fb = df_test_2_c_fb.groupby(['n', 'V'], as_index=False, sort=False).mean()
df_test_2_c_bt = df_test_2_c_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()

# renombro las columnas en cada dataframe y los mergeo en uno solo
df_test_2_c_fb.columns = ['n', 'V', 'tiempo (fuerzabruta)']
df_test_2_c_bt.columns = ['n', 'V', 'tiempo (backtracking)']

df_test_2_c = df_test_2_c_fb
df_test_2_c['tiempo (backtracking)'] = df_test_2_c_bt['tiempo (backtracking)']

# grafico
a4_dims = (6.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 2))
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1 = sns.lineplot(x="n", y="tiempo (fuerzabruta)", data=df_test_2_c, label='Fuerza Bruta', ax=ax);
ax1 = sns.lineplot(x="n", y="tiempo (backtracking)", data=df_test_2_c, label='Backtracking (Poda de todo el árbol excepto una rama)', ax=ax);

plt.ylim(-0.05,2)


plt.ylabel("Tiempo de ejecución [ms]", fontsize=16);
plt.xlabel("n", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None, None]

# %% [markdown]
# <h3>Yapa: Extender el rango de n</h3>

# %%
df_test_2_c_yapa_bt = pd.read_csv('output/test-2-c-yapa-backtracking.csv')
del df_test_2_c_yapa_bt['resultado']

# Obtengo el promedio en cada tabla
df_test_2_c_yapa_bt = df_test_2_c_yapa_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()

# renombro las columnas en cada dataframe y los mergeo en uno solo
df_test_2_c_yapa_bt.columns = ['n', 'V', 'tiempo (backtracking)']

df_test_2_c_yapa = df_test_2_c_yapa_bt

# grafico
a4_dims = (6.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 1))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1 = sns.lineplot(x="n", y="tiempo (backtracking)", data=df_test_2_c_yapa, label='Backtracking (Poda de todo el árbol)', ax=ax);

plt.ylim(-0.05,2)

plt.ylabel("Tiempo de ejecución [ms]", fontsize=16);
plt.xlabel("n", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-7-7826e6f906c7> in <module>()
#       3
#       4 # Obtengo el promedio en cada tabla
# ----> 5 df_test_2_c_yapa_bt = df_test_2_c_yapa_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()
#       6
#       7 # renombro las columnas en cada dataframe y los mergeo en uno solo
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
# -> 1306             return self._cython_agg_general('mean', **kwargs)
#    1307         except GroupByError:
#    1308             raise
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    3970                             min_count=-1):
# ...

# %% [markdown]
# <h3>Comparación backtracking sin podas vs backtracking con poda de medio árbol vs backtracking con poda de todo el árbol vs backtracking con poda de todo el arbol menos una rama</h3>

# %% [markdown]
# <h1>Test 3</h1>

# %%
df_test_3_bt = pd.read_csv('output/test-3-backtracking.csv')
del df_test_3_bt['resultado']

df_test_3_pd = pd.read_csv('output/test-3-programaciondinamica.csv')
del df_test_3_pd['resultado']

# Obtengo el promedio en cada tabla
df_test_3_bt = df_test_3_bt.groupby(['n', 'V'], as_index=False, sort=False).mean()
df_test_3_pd = df_test_3_pd.groupby(['n', 'V'], as_index=False, sort=False).mean()

# renombro las columnas en cada dataframe y los mergeo en uno solo
df_test_3_bt.columns = ['n', 'V', 'tiempo (backtracking)']
df_test_3_pd.columns = ['n', 'V', 'tiempo (programaciondinamica)']

df_test_3 = df_test_3_bt
df_test_3['tiempo (programaciondinamica)'] = df_test_3_pd['tiempo (programaciondinamica)']

# grafico
a4_dims = (6.75, 3.975)
fig, ax = plt.subplots(figsize=a4_dims)
sns.set_palette(sns.color_palette("cubehelix", 2))
sns.set_style("whitegrid")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

df_test_3['n*V'] = df_test_3['n'] * df_test_3['V'] 

ax1 = sns.lineplot(x="n", y="tiempo (programaciondinamica)", data=df_test_3, label='Programación Dinámica', ax=ax);
ax1 = sns.lineplot(x="n", y="tiempo (backtracking)", data=df_test_3, label='Backtracking', ax=ax);


plt.ylabel("Tiempo de ejecución [ms]", fontsize=16);
plt.xlabel("n", fontsize=16);
plt.tick_params(labelsize=14)
plt.setp(ax.lines,linewidth=3)
# Out:
# [None, None]
